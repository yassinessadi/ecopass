# %%
import pyarrow.parquet as pq
import pandas as pd


table = pq.read_table("./spddimp_dir/")
df = table.to_pandas()

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Display DataFrame
print(df)
